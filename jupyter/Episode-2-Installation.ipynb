# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '1.3.1'

# %%
import os

# Get API Token
API_TOKEN = "e4c1f70a2a7d56e717611889aa84abb5f3693ed7d8ca2da5a3010d5dbdf0ebe4526a85afa9fd4d8e47a7e015b4d1b3fff5314cd7dd04d86931e4c4142db9b13c"

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel = "ibm_quantum", # IBM Cloud (ibm_cloud)
    token=API_TOKEN,
)

# %%
backend = service.backend(name = "ibm_brisbane")

# %%
backend.num_qubits
# Out:
# 127
